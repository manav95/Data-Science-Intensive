# %%
# %matplotlib inline
import pandas as pd

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
titles = pd.DataFrame.from_csv('data/titles.csv', index_col=None)
titles.head()
# Out:
#                    title  year
# 0              Stockholm  2018
# 1     Parlez-moi d'amour  1935
# 2  Tom's Midnight Garden  1999
# 3          Believe in Me  2006
# 4           Arnolds Park  2007

# %%
cast = pd.DataFrame.from_csv('data/cast.csv', index_col=None)
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
len(titles)
# Out:
# 236324

# %%
#236324

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
titles.sort_values('year', ascending=True)
# Out:
#                                                     title  year
# 3957                                           Miss Jerry  1894
# 37353                                  The Startled Lover  1898
# 115728     Reproduction of the Corbett and Jeffries Fight  1899
# 211489  Pierrot's Problem, or How to Make a Fat Wife O...  1900
# 116405                           Trouble in Hogan's Alley  1900
# 193940                                     May Day Parade  1900
# 148203                               Family Troubles (II)  1900
# 219249                              Soldiers of the Cross  1900
# 212942                                        The Divorce  1903
# 149358                                  La malia dell'oro  1905
# 15569                                             Valsons  1905
# 35483                                       Lika mot lika  1906
# 198107                 The Joe Gans-Battling Nelson Fight  1906
# 94269                         The Story of the Kelly Gang  1906
# ...

# %%
#Miss Jerry The Startled Lover

# %% [markdown]
# ### How many movies have the title "Hamlet"?

# %%
len(titles[titles.title == "Hamlet"])
# Out:
# 20

# %%
#20

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
len(titles[titles.title == "North by Northwest"])
# Out:
# 1

# %%
#1

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
titles[titles.title == "Hamlet"].sort_values("year")
# Out:
#          title  year
# 97797   Hamlet  1910
# 153278  Hamlet  1911
# 34185   Hamlet  1913
# 22353   Hamlet  1921
# 207013  Hamlet  1948
# 134358  Hamlet  1954
# 221133  Hamlet  1964
# 211462  Hamlet  1969
# 206304  Hamlet  1973
# 58785   Hamlet  1976
# 23710   Hamlet  1987
# 219005  Hamlet  1990
# 110161  Hamlet  1996
# 17980   Hamlet  2000
# 201550  Hamlet  2009
# 106553  Hamlet  2011
# 233231  Hamlet  2014
# 186567  Hamlet  2015
# 66958   Hamlet  2016
# 143107  Hamlet  2017

# %%
#1910

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
titles[titles.title == "Treasure Island"].sort_values("year")
# Out:
#                   title  year
# 189876  Treasure Island  1918
# 120123  Treasure Island  1920
# 161216  Treasure Island  1934
# 155281  Treasure Island  1950
# 159025  Treasure Island  1972
# 82652   Treasure Island  1973
# 85824   Treasure Island  1985
# 174538  Treasure Island  1999

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
len(titles[titles.year == 1950])
# Out:
# 1112

# %%
#1112

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
len(titles[titles.year == 1960])
# Out:
# 1533

# %%
#1533

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
len(t[(t.year >= 1950) & (t.year <= 1959)])
# Out:
# 12869

# %%
#12869

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
t[t.title == "Batman"].year
# Out:
# 57893     1989
# 167141    1943
# Name: year, dtype: int64

# %%
#1989 1943

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
len(cast[cast.title == 'Inception'])
# Out:
# 78

# %%
#78

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
incCast = cast[cast.title == 'Inception']
len(incCast[incCast.n.isnull()])
# Out:
# 27

# %%
#27

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
incCast = cast[cast.title == 'Inception']
len(incCast[incCast.n.notnull()])
# Out:
# 51

# %%
#51

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
northwestCast = cast[cast.title == 'North by Northwest']
northwestCast[northwestCast.n.notnull()].sort_values('n')
# Out:
#                       title  year                  name     type  \
# 867494   North by Northwest  1959            Cary Grant    actor
# 3474189  North by Northwest  1959       Eva Marie Saint  actress
# 1450069  North by Northwest  1959           James Mason    actor
# 3124771  North by Northwest  1959   Jessie Royce Landis  actress
# 355162   North by Northwest  1959        Leo G. Carroll    actor
# 3019791  North by Northwest  1959  Josephine Hutchinson  actress
# 1687010  North by Northwest  1959           Philip Ober    actor
# 1268932  North by Northwest  1959         Martin Landau    actor
# 2435182  North by Northwest  1959         Adam Williams    actor
# 1802517  North by Northwest  1959          Edward Platt    actor
# 662839   North by Northwest  1959     Robert Ellenstein    actor
# 2284548  North by Northwest  1959          Les Tremayne    actor
# 462692   North by Northwest  1959       Philip Coolidge    actor
# ...

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
filmCast = cast[(cast.title == 'Sleuth') & (cast.year == 1972)]
filmCast.sort_values('n')
# Out:
#           title  year                name     type  \
# 1697110  Sleuth  1972    Laurence Olivier    actor
# 325302   Sleuth  1972       Michael Caine    actor
# 372290   Sleuth  1972      Alec Cawthorne    actor
# 1458303  Sleuth  1972  John (II) Matthews    actor
# 2705900  Sleuth  1972  Eve (III) Channing  actress
# 1441628  Sleuth  1972        Teddy Martin    actor
#
#                           character    n
# 1697110                 Andrew Wyke  1.0
# 325302                  Milo Tindle  2.0
# 372290            Inspector Doppler  3.0
# 1458303  Detective Sergeant Tarrant  4.0
# 2705900             Marguerite Wyke  5.0
# 1441628      Police Constable Higgs  6.0

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
filmCast = cast[(cast.title == 'Sleuth') & (cast.year == 2007)]
filmCast.sort_values('n')
# Out:
#           title  year                 name     type          character    n
# 325303   Sleuth  2007        Michael Caine    actor             Andrew  1.0
# 1287140  Sleuth  2007             Jude Law    actor               Milo  2.0
# 1797079  Sleuth  2007        Harold Pinter    actor        Man on T.V.  3.0
# 258968   Sleuth  2007      Kenneth Branagh    actor  Other Man on T.V.  NaN
# 372291   Sleuth  2007  Alec (II) Cawthorne    actor  Inspector Doppler  NaN
# 2705899  Sleuth  2007    Eve (II) Channing  actress    Marguerite Wyke  NaN
# 3331103  Sleuth  2007    Carmel O'Sullivan  actress             Maggie  NaN

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
hamCast = cast[(cast.title == 'Hamlet') & (cast.year == 1921)]
len(hamCast)
# Out:
# 9

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
newHamCast = cast[(cast.title == 'Hamlet') & (cast.year == 1996)]
len(newHamCast)
# Out:
# 54

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %%
hamChar = cast[cast.character == 'Hamlet']
len(hamChar)
# Out:
# 95

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
opheliaChar = cast[cast.character == 'Ophelia']
len(opheliaChar)
# Out:
# 113

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %%
theDudes = cast[cast.character == 'The Dude']
len(theDudes)
# Out:
# 18

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %%
strangerChar = cast[cast.character == 'The Stranger']
len(strangerChar)
# Out:
# 213

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %% [markdown]
# ### How many roles has Judi Dench played?

# %%
# Out:
#                                                 title  year  \
# 0                                      Closet Monster  2015
# 1                                     Suuri illusioni  1985
# 2                                 Battle of the Sexes  2017
# 3                                Secret in Their Eyes  2015
# 4                                          Steve Jobs  2015
# 5                              Straight Outta Compton  2015
# 6                              Straight Outta Compton  2015
# 7                                      For Thy Love 2  2009
# 8   Lapis, Ballpen at Diploma, a True to Life Journey  2014
# 9                                        Desire (III)  2014
# 10                            When the Man Went South  2014
# 11                            Little Angel (Angelita)  2015
# 12                                         Mixing Nia  1998
# 13                                   The Replacements  2000
#
#                           name   type  \
# ...

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
caryChar = cast[(cast.name == 'Cary Grant') & (cast.n == 2.0)]
caryChar.sort_values('year')
# Out:
#                          title  year        name   type  \
# 867485        Madame Butterfly  1932  Cary Grant  actor
# 867504      She Done Him Wrong  1933  Cary Grant  actor
# 867522       The Woman Accused  1933  Cary Grant  actor
# 867514  The Eagle and the Hawk  1933  Cary Grant  actor
# 867479            I'm No Angel  1933  Cary Grant  actor
# 867523     Thirty-Day Princess  1934  Cary Grant  actor
# 867460          Born to Be Bad  1934  Cary Grant  actor
# 867508         Sylvia Scarlett  1935  Cary Grant  actor
# 867468           Enter Madame!  1935  Cary Grant  actor
# 867533       Wings in the Dark  1935  Cary Grant  actor
# 867531         Wedding Present  1936  Cary Grant  actor
# 867532     When You're in Love  1937  Cary Grant  actor
# 867511         The Awful Truth  1937  Cary Grant  actor
# 867521   The Toast of New York  1937  Cary Grant  actor
# 867527                  Topper  1937  Cary Grant  actor
# 867475                 Holiday  1938  Cary Grant  actor
# ...

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %%
caryChar = cast[(cast.name == 'Cary Grant') & (cast.n == 1.0)]
caryChar.sort_values('year')
# Out:
#                                        title  year        name   type  \
# 867476                          Hot Saturday  1932  Cary Grant  actor
# 867471                         Gambling Ship  1933  Cary Grant  actor
# 867484                  Ladies Should Listen  1934  Cary Grant  actor
# 867482                      Kiss and Make-Up  1934  Cary Grant  actor
# 867517                      The Last Outpost  1935  Cary Grant  actor
# 867510     The Amazing Quest of Ernest Bliss  1936  Cary Grant  actor
# 867458                        Big Brown Eyes  1936  Cary Grant  actor
# 867499                Only Angels Have Wings  1939  Cary Grant  actor
# 867473                             Gunga Din  1939  Cary Grant  actor
# 867518                The Philadelphia Story  1940  Cary Grant  actor
# 867474                       His Girl Friday  1940  Cary Grant  actor
# 867516               The Howards of Virginia  1940  Cary Grant  actor
# ...

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %%
fiftiesChar = cast[(cast.year >= 2010) & (cast.year <= 2020) & (cast.type == 'actor')]
len(fiftiesChar)
# Out:
# 741222

# %% [markdown]
# ### How many roles were avilable for actresses in the 1950s?

# %%
femChar = cast[(cast.year >= 2010) & (cast.year <= 2020) & (cast.type == 'actress')]
len(femChar)
# Out:
# 415809

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
femChar = cast[(cast.year <= 1980) & (cast.n == 1.0)]
len(femChar)
# Out:
# 64780

# %%
#64780

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %%
femChar = cast[(cast.year <= 1980) & (cast.n != 1.0)]
len(femChar)
# Out:
# 1110597

# %%
#1110597

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
miscellanyChar = cast[(cast.year <= 1980) & (cast.n.isnull())]
len(miscellanyChar)
# Out:
# 445386

# %%
len(titles)
# Out:
# 236324

# %%
titles
# Out:
#                                           title  year
# 0                                     Stockholm  2018
# 1                            Parlez-moi d'amour  1935
# 2                         Tom's Midnight Garden  1999
# 3                                 Believe in Me  2006
# 4                                  Arnolds Park  2007
# 5                              The Harvest Moon  1920
# 6                               Ae Fond Kiss...  2004
# 7                                      Fake-Out  1982
# 8                                          1985  2018
# 9                                          Seed  2009
# 10      To Love is Enemy of the Great Dull Void  2014
# 11                  Intikam Melegi/Kadin Hamlet  1976
# 12                      The Godfather: Part III  1990
# 13                                Made in China  2009
# 14                                College Girls  1968
# 15                    Kiekeboe: Het witte bloed  1992
# ...

# %%
len(titles)
# Out:
# 236324

# %%
titles.head()
# Out:
#                    title  year
# 0              Stockholm  2018
# 1     Parlez-moi d'amour  1935
# 2  Tom's Midnight Garden  1999
# 3          Believe in Me  2006
# 4           Arnolds Park  2007

# %%
h = titles.head(32)
len(h)
# Out:
# 32

# %%
h['year']
# Out:
# 0    2018
# 1    1935
# 2    1999
# 3    2006
# 4    2007
# 5    1920
# 6    2004
# 7    1982
# Name: year, dtype: int64

# %%
h.year > 1985
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4      True
# 5     False
# 6      True
# 7     False
# 8      True
# 9      True
# 10     True
# 11    False
# 12     True
# 13     True
# 14    False
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23    False
# 24     True
# 25     True
# 26    False
# 27    False
# 28     True
# 29     True
# 30     True
# 31    False
# Name: year, dtype: bool

# %%
h[(h.year < 1980) | (h.year >= 1990)] # or: |
# Out:
#                                       title  year
# 0                                 Stockholm  2018
# 1                        Parlez-moi d'amour  1935
# 2                     Tom's Midnight Garden  1999
# 3                             Believe in Me  2006
# 4                              Arnolds Park  2007
# 5                          The Harvest Moon  1920
# 6                           Ae Fond Kiss...  2004
# 8                                      1985  2018
# 9                                      Seed  2009
# 10  To Love is Enemy of the Great Dull Void  2014
# 11              Intikam Melegi/Kadin Hamlet  1976
# 12                  The Godfather: Part III  1990
# 13                            Made in China  2009
# 14                            College Girls  1968
# 15                Kiekeboe: Het witte bloed  1992
# 16                            Bin ich sexy?  2004
# 17                            Life for Rent  2012
# 18                                  Hajwala  2016
# ...

# %%
t = titles
t[t.title == 'Macbeth'].sort_values('year').tail()
# Out:
#           title  year
# 60742   Macbeth  2012
# 9044    Macbeth  2013
# 229252  Macbeth  2014
# 22868   Macbeth  2015
# 173337  Macbeth  2017

# %%
cast
# Out:
#                                                      title  year  \
# 0                                           Closet Monster  2015
# 1                                          Suuri illusioni  1985
# 2                                      Battle of the Sexes  2017
# 3                                     Secret in Their Eyes  2015
# 4                                               Steve Jobs  2015
# 5                                   Straight Outta Compton  2015
# 6                                   Straight Outta Compton  2015
# 7                                           For Thy Love 2  2009
# 8        Lapis, Ballpen at Diploma, a True to Life Journey  2014
# 9                                             Desire (III)  2014
# 10                                 When the Man Went South  2014
# 11                                 Little Angel (Angelita)  2015
# 12                                              Mixing Nia  1998
# ...

# %%
h = cast.head()
h = h[h.n.isnull()]
h
# Out:
#                   title  year     name   type                character   n
# 3  Secret in Their Eyes  2015  $hutter  actor          2002 Dodger Fan NaN
# 4            Steve Jobs  2015  $hutter  actor  1988 Opera House Patron NaN

# %%
'Hamlet (II)'.startswith('Hamlet')
# Out:
# True

# %%
titles.title.str.startswith('The').head(15)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# Name: title, dtype: bool

# %%
titles.year.value_counts().sort_index().plot()

# %%
c = cast
c = c[c.character == 'Kermit the Frog']
c.plot(x='year', y='n',kind='scatter')

# %%
c.head()[['year', 'n']]
# Out:
#         year     n
# 978133  1981  18.0
# 978134  1985   2.0
# 978139  1981   1.0
# 978147  1979   1.0
# 978154  1984   1.0
